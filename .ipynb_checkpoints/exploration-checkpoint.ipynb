# %%
import os
import sys
from importlib import reload

import external as ext

# %%
reload(ext)
# Out:
# <module 'external' from '/home/jm/Development/Github/crossfit_webscraping/external.py'>

# %% [markdown]
# # Test the leaderboard data collection

# %%
year=2018
division=1
scaled=0
page=1

# Get the data from the leaderboard
data_collected=ext.get_leaderboarddetails(year,division,scaled,page)

# %%
data_collected['leaderboardRows']
# Out:
# [{'entrant': {'affiliateId': '3220',
#    'affiliateName': 'CrossFit Mayhem',
#    'age': '28',
#    'competitorId': '153604',
#    'competitorName': 'Mathew Fraser',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Mathew',
#    'gender': 'M',
#    'height': '67 in',
#    'lastName': 'Fraser',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '9e218-P153604_4-184.jpg',
#    'regionId': '6',
#    'regionName': 'Central East',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '190 lb'},
#   'nextStage': '',
#   'overallRank': '1',
#   'overallScore': '97',
#   'scores': [{'affiliate': 'CrossFit Mayhem',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n10 clean & jerks\n10 calories',
#     'heat': '',
#     'judge': 'Anthony Jay Wilkerson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '4',
#     'scaled': '0',
#     'score': '14760000',
#     'scoreDisplay': '476 reps',
#     'scoreIdentifier': '7db296c93cdcd76984d0',
#     'video': '0'},
#    {'affiliate': 'CrossFit Columbus',
#     'breakdown': '110 reps\n380 lb.',
#     'heat': '',
#     'judge': "Matt O'Keefe",
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '49',
#     'scaled': '0',
#     'score': '11100478',
#     'scoreDisplay': '4:02',
#     'scoreIdentifier': '1d74d1f4354623081c9b',
#     'time': 242,
#     'video': '0'},
#    {'affiliate': 'CrossFit Columbus',
#     'breakdown': '380 lb.',
#     'heat': '',
#     'judge': "Matt O'Keefe",
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '21',
#     'scaled': '0',
#     'score': '13800478',
#     'scoreDisplay': '380 lb',
#     'scoreIdentifier': 'afbbb6f5b45f455dcff0',
#     'time': 242,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n100 double-unders',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '17',
#     'scaled': '0',
#     'score': '19160001',
#     'scoreDisplay': '916 reps',
#     'scoreIdentifier': 'f2684dc0303098b9910e',
#     'time': 839,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Angelo Dicicco',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '5',
#     'scaled': '0',
#     'score': '11650141',
#     'scoreDisplay': '6:39',
#     'scoreIdentifier': 'dd5db69df61f61688062',
#     'time': 399,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n24 thr. 6 PU',
#     'heat': '',
#     'judge': 'Lindy Barber',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '1',
#     'scaled': '0',
#     'score': '11980000',
#     'scoreDisplay': '198 reps',
#     'scoreIdentifier': '5cfc2044268b98cafe01',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '10990',
#    'affiliateName': 'CrossFit Quebec City',
#    'age': '26',
#    'competitorId': '180541',
#    'competitorName': 'Alex Vigneault',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Alex',
#    'gender': 'M',
#    'height': '71 in',
#    'lastName': 'Vigneault',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': 'ebe1c-P180541_4-184.jpg',
#    'regionId': '18',
#    'regionName': 'Canada East',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '208 lb'},
#   'nextStage': '',
#   'overallRank': '2',
#   'overallScore': '439',
#   'scores': [{'affiliate': 'CrossFit Quebec City',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n10 clean & jerks\n6 calories',
#     'heat': '',
#     'judge': 'Alice Guérin',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '11',
#     'scaled': '0',
#     'score': '14720000',
#     'scoreDisplay': '472 reps',
#     'scoreIdentifier': '46d85c9febc169945588',
#     'video': '0'},
#    {'affiliate': 'CrossFit Quebec City',
#     'breakdown': '110 reps\n382 lb.',
#     'heat': '',
#     'judge': 'Alice Guérin',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '249',
#     'scaled': '0',
#     'score': '11100462',
#     'scoreDisplay': '4:18',
#     'scoreIdentifier': '0c1789e3dc8c0b22d7e5',
#     'time': 258,
#     'video': '0'},
#    {'affiliate': 'CrossFit Quebec City',
#     'breakdown': '382 lb.',
#     'heat': '',
#     'judge': 'Alice Guérin',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '17',
#     'scaled': '0',
#     'score': '13820462',
#     'scoreDisplay': '382 lb',
#     'scoreIdentifier': '3f040933617ace6a981d',
#     'time': 258,
#     'video': '0'},
#    {'affiliate': 'CrossFit Quebec City',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches',
#     'heat': '',
#     'judge': 'Alice Guérin',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '109',
#     'scaled': '0',
#     'score': '18160043',
#     'scoreDisplay': '816 reps',
#     'scoreIdentifier': '0357d6e44a3469b5244d',
#     'time': 797,
#     'video': '0'},
#    {'affiliate': 'CrossFit Quebec City',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Alice Guérin',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '7',
#     'scaled': '0',
#     'score': '11650132',
#     'scoreDisplay': '6:48',
#     'scoreIdentifier': '1a5ebfe71587fdb680d6',
#     'time': 408,
#     'video': '0'},
#    {'affiliate': 'CrossFit Quebec City',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n11 thr.',
#     'heat': '',
#     'judge': 'Benjamin Hebert',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '46',
#     'scaled': '0',
#     'score': '11790000',
#     'scoreDisplay': '179 reps',
#     'scoreIdentifier': 'cbfcea95054f8266f064',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '16786',
#    'affiliateName': 'CrossFit DBS 83',
#    'age': '25',
#    'competitorId': '702092',
#    'competitorName': 'Willy Georges',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Willy',
#    'gender': 'M',
#    'height': '179 cm',
#    'lastName': 'Georges',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '9ca60-P702092_3-184.jpg',
#    'regionId': '24',
#    'regionName': 'Europe South',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '86 kg'},
#   'nextStage': '',
#   'overallRank': '3',
#   'overallScore': '596',
#   'scores': [{'affiliate': 'CrossFit DBS 83',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n4 clean & jerks',
#     'heat': '',
#     'judge': 'Anthony De Giacinto',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '43',
#     'scaled': '0',
#     'score': '14600000',
#     'scoreDisplay': '460 reps',
#     'scoreIdentifier': '02de0850847a45a53da0',
#     'video': '0'},
#    {'affiliate': 'CrossFit DBS 83',
#     'breakdown': '110 reps\n364 lb.',
#     'heat': '',
#     'judge': 'Mylene Jankovits',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '223',
#     'scaled': '0',
#     'score': '11100463',
#     'scoreDisplay': '4:17',
#     'scoreIdentifier': '6531a26c1a1114dce4cf',
#     'time': 257,
#     'video': '0'},
#    {'affiliate': 'CrossFit DBS 83',
#     'breakdown': '364 lb.',
#     'heat': '',
#     'judge': 'Mylene Jankovits',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '122',
#     'scaled': '0',
#     'score': '13640463',
#     'scoreDisplay': '364 lb',
#     'scoreIdentifier': '851ac9840f3a3cc68473',
#     'time': 257,
#     'video': '0'},
#    {'affiliate': 'CrossFit DBS 83',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n60 double-unders',
#     'heat': '',
#     'judge': 'Mylene Jankovits',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '38',
#     'scaled': '0',
#     'score': '18760078',
#     'scoreDisplay': '876 reps',
#     'scoreIdentifier': '0ec7db7cce1b1f76970f',
#     'time': 762,
#     'video': '0'},
#    {'affiliate': 'CrossFit DBS 83',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Mylene Jankovits',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '165',
#     'scaled': '0',
#     'score': '11650039',
#     'scoreDisplay': '8:21',
#     'scoreIdentifier': '8ec0219024f749eb2724',
#     'time': 501,
#     'video': '0'},
#    {'affiliate': 'CrossFit DBS 83',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n20 thr.',
#     'heat': '',
#     'judge': 'Mylene Jankovits',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '5',
#     'scaled': '0',
#     'score': '11880000',
#     'scoreDisplay': '188 reps',
#     'scoreIdentifier': 'b23cef1e3fa6c05da8e8',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '4459',
#    'affiliateName': 'Tonic CrossFit',
#    'age': '24',
#    'competitorId': '308712',
#    'competitorName': 'Jean-Simon Roy-Lemaire',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Jean-Simon',
#    'gender': 'M',
#    'height': '176 cm',
#    'lastName': 'Roy-Lemaire',
#    'postCompStatus': 'accepted',
#    'profession': '1',
#    'profilePicS3key': '47f1f-P308712_3-184.jpg',
#    'regionId': '18',
#    'regionName': 'Canada East',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '195 lb'},
#   'nextStage': '',
#   'overallRank': '4',
#   'overallScore': '681',
#   'scores': [{'affiliate': 'Tonic CrossFit',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n10 clean & jerks\n2 calories',
#     'heat': '',
#     'judge': 'Mathieu Gravel',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '18',
#     'scaled': '0',
#     'score': '14680000',
#     'scoreDisplay': '468 reps',
#     'scoreIdentifier': '133e96b36cdb1078a745',
#     'video': '0'},
#    {'affiliate': 'Tonic CrossFit',
#     'breakdown': '110 reps\n346 lb.',
#     'heat': '',
#     'judge': 'Mathieu Gravel',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '26',
#     'scaled': '0',
#     'score': '11100482',
#     'scoreDisplay': '3:58',
#     'scoreIdentifier': '879d6a1792b85a0d3251',
#     'time': 238,
#     'video': '0'},
#    {'affiliate': 'Tonic CrossFit',
#     'breakdown': '346 lb.',
#     'heat': '',
#     'judge': 'Mathieu Gravel',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '396',
#     'scaled': '0',
#     'score': '13460482',
#     'scoreDisplay': '346 lb',
#     'scoreIdentifier': 'e5a25d9c1e8d485ee2f2',
#     'time': 238,
#     'video': '0'},
#    {'affiliate': 'Tonic CrossFit',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches',
#     'heat': '',
#     'judge': 'Mathieu Gravel',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '112',
#     'scaled': '0',
#     'score': '18160040',
#     'scoreDisplay': '816 reps',
#     'scoreIdentifier': '296e90c5eeafcc5cca48',
#     'time': 800,
#     'video': '0'},
#    {'affiliate': 'Tonic CrossFit',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Mathieu Gravel',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '75',
#     'scaled': '0',
#     'score': '11650077',
#     'scoreDisplay': '7:43',
#     'scoreIdentifier': '655fd6398d6e99197b16',
#     'time': 463,
#     'video': '0'},
#    {'affiliate': 'Tonic CrossFit',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n10 thr.',
#     'heat': '',
#     'judge': 'Isabelle Chouinard',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '54',
#     'scaled': '0',
#     'score': '11780000',
#     'scoreDisplay': '178 reps',
#     'scoreIdentifier': 'b07b2adccdb2a8cee143',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '6214',
#    'affiliateName': 'CrossFit Solid Ground',
#    'age': '28',
#    'competitorId': '158264',
#    'competitorName': 'Patrick Vellner',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Patrick',
#    'gender': 'M',
#    'height': '71 in',
#    'lastName': 'Vellner',
#    'postCompStatus': 'accepted',
#    'profession': '128',
#    'profilePicS3key': '9bfee-P158264_6-184.jpg',
#    'regionId': '18',
#    'regionName': 'Canada East',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '195 lb'},
#   'nextStage': '',
#   'overallRank': '5',
#   'overallScore': '706',
#   'scores': [{'affiliate': 'CrossFit Solid Ground',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n10 clean & jerks\n10 calories',
#     'heat': '',
#     'judge': 'Jonathan Mulder',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '4',
#     'scaled': '0',
#     'score': '14760000',
#     'scoreDisplay': '476 reps',
#     'scoreIdentifier': '015f0e819ca5ee359be3',
#     'video': '0'},
#    {'affiliate': 'CrossFit Solid Ground',
#     'breakdown': '110 reps\n343 lb.',
#     'heat': '',
#     'judge': 'Justin Tamane',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '78',
#     'scaled': '0',
#     'score': '11100474',
#     'scoreDisplay': '4:06',
#     'scoreIdentifier': '898e7b76f4468dfd0eed',
#     'time': 246,
#     'video': '0'},
#    {'affiliate': 'CrossFit Solid Ground',
#     'breakdown': '343 lb.',
#     'heat': '',
#     'judge': 'Justin Tamane',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '501',
#     'scaled': '0',
#     'score': '13430474',
#     'scoreDisplay': '343 lb',
#     'scoreIdentifier': 'f7f213128cf56ac0b2f9',
#     'time': 246,
#     'video': '0'},
#    {'affiliate': 'CrossFit Solid Ground',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n100 double-unders\n1 bar muscle-ups',
#     'heat': '',
#     'judge': 'Justin Tamane',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '16',
#     'scaled': '0',
#     'score': '19170005',
#     'scoreDisplay': '917 reps',
#     'scoreIdentifier': '2e5be1768968ceecc850',
#     'time': 835,
#     'video': '0'},
#    {'affiliate': 'CrossFit Solid Ground',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Justin Tamane',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '9',
#     'scaled': '0',
#     'score': '11650131',
#     'scoreDisplay': '6:49',
#     'scoreIdentifier': 'a67d0860bcd542108b20',
#     'time': 409,
#     'video': '0'},
#    {'affiliate': 'CrossFit Solid Ground',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n6 thr.',
#     'heat': '',
#     'judge': 'Jonathan Mulder',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '98',
#     'scaled': '0',
#     'score': '11740000',
#     'scoreDisplay': '174 reps',
#     'scoreIdentifier': '4a145b94c69022708def',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '15562',
#    'affiliateName': 'CrossFit Levis',
#    'age': '22',
#    'competitorId': '251546',
#    'competitorName': 'Alexandre Caron',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Alexandre',
#    'gender': 'M',
#    'height': '71 in',
#    'lastName': 'Caron',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '92bcf-P251546_4-184.jpg',
#    'regionId': '18',
#    'regionName': 'Canada East',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '200 lb'},
#   'nextStage': '',
#   'overallRank': '6',
#   'overallScore': '813',
#   'scores': [{'affiliate': 'CrossFit Levis',
#     'breakdown': '14 rounds +\n0 toes-to-bars',
#     'heat': '',
#     'judge': 'Anne',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '143',
#     'scaled': '0',
#     'score': '14480000',
#     'scoreDisplay': '448 reps',
#     'scoreIdentifier': '5fcc548599fc483da29d',
#     'video': '0'},
#    {'affiliate': 'CrossFit Levis',
#     'breakdown': '110 reps\n347 lb.',
#     'heat': '',
#     'judge': 'David Cyr',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '5',
#     'scaled': '0',
#     'score': '11100491',
#     'scoreDisplay': '3:49',
#     'scoreIdentifier': '298500f7a17fa06d7113',
#     'time': 229,
#     'video': '0'},
#    {'affiliate': 'CrossFit Levis',
#     'breakdown': '347 lb.',
#     'heat': '',
#     'judge': 'David Cyr',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '348',
#     'scaled': '0',
#     'score': '13470491',
#     'scoreDisplay': '347 lb',
#     'scoreIdentifier': 'e7dcf810809b05805692',
#     'time': 229,
#     'video': '0'},
#    {'affiliate': 'CrossFit Levis',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches',
#     'heat': '',
#     'judge': 'Anne',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '100',
#     'scaled': '0',
#     'score': '18160051',
#     'scoreDisplay': '816 reps',
#     'scoreIdentifier': '609913be79b6dd9b2f57',
#     'time': 789,
#     'video': '0'},
#    {'affiliate': 'CrossFit Levis',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Anne',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '61',
#     'scaled': '0',
#     'score': '11650082',
#     'scoreDisplay': '7:38',
#     'scoreIdentifier': '992c51de240bcb9d0885',
#     'time': 458,
#     'video': '0'},
#    {'affiliate': 'CrossFit Levis',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n3 thr.',
#     'heat': '',
#     'judge': 'Fred Bissonnette',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '156',
#     'scaled': '0',
#     'score': '11710000',
#     'scoreDisplay': '171 reps',
#     'scoreIdentifier': '22deaa5906fb25e30111',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '17335',
#    'affiliateName': 'CrossFit Kilo II',
#    'age': '23',
#    'competitorId': '247005',
#    'competitorName': 'Streat Hoerner',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Streat',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Hoerner',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '0e176-P247005_2-184.jpg',
#    'regionId': '10',
#    'regionName': 'North Central',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '198 lb'},
#   'nextStage': '',
#   'overallRank': '7',
#   'overallScore': '826',
#   'scores': [{'affiliate': 'CrossFit Kilo II',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n6 clean & jerks',
#     'heat': '',
#     'judge': 'Chase Bushaw',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '34',
#     'scaled': '0',
#     'score': '14620000',
#     'scoreDisplay': '462 reps',
#     'scoreIdentifier': '4dc82c202e5b4e37287a',
#     'video': '0'},
#    {'affiliate': 'CrossFit Kilo II',
#     'breakdown': '110 reps\n342 lb.',
#     'heat': '',
#     'judge': 'Chase Bushaw',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '146',
#     'scaled': '0',
#     'score': '11100468',
#     'scoreDisplay': '4:12',
#     'scoreIdentifier': 'd1dd76eab84e648b0b20',
#     'time': 252,
#     'video': '0'},
#    {'affiliate': 'CrossFit Kilo II',
#     'breakdown': '342 lb.',
#     'heat': '',
#     'judge': 'Chase Bushaw',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '524',
#     'scaled': '0',
#     'score': '13420468',
#     'scoreDisplay': '342 lb',
#     'scoreIdentifier': '88812a28663aa0b9b78a',
#     'time': 252,
#     'video': '0'},
#    {'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n25 double-unders',
#     'heat': '',
#     'judge': 'Luke Schafer',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '63',
#     'scaled': '0',
#     'score': '18410058',
#     'scoreDisplay': '841 reps',
#     'scoreIdentifier': 'be199d5a66ccd9e45048',
#     'time': 782,
#     'video': '0'},
#    {'affiliate': 'CrossFit Kilo II',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Austin Nedelcoff',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '32',
#     'scaled': '0',
#     'score': '11650102',
#     'scoreDisplay': '7:18',
#     'scoreIdentifier': '5102d6dfc62c9d3b2d4d',
#     'time': 438,
#     'video': '0'},
#    {'affiliate': 'CrossFit Alioth',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n13 thr.',
#     'heat': '',
#     'judge': 'Mikko Aronpaa',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '27',
#     'scaled': '0',
#     'score': '11810000',
#     'scoreDisplay': '181 reps',
#     'scoreIdentifier': 'eaf08edd820ecdd591aa',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '14664',
#    'affiliateName': 'CrossFit Rejoice',
#    'age': '27',
#    'competitorId': '123764',
#    'competitorName': 'Logan Collins',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Logan',
#    'gender': 'M',
#    'height': '67 in',
#    'lastName': 'Collins',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '5afca-P123764_4-184.jpg',
#    'regionId': '14',
#    'regionName': 'South Central',
#    'regionalCode': '7',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '175 lb'},
#   'nextStage': '',
#   'overallRank': '8',
#   'overallScore': '836',
#   'scores': [{'affiliate': 'CrossFit Rejoice',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks\n7 calories',
#     'heat': '',
#     'judge': 'Sara Singer',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '289',
#     'scaled': '0',
#     'score': '14410000',
#     'scoreDisplay': '441 reps',
#     'scoreIdentifier': 'fcb45e00de9472f7f961',
#     'video': '0'},
#    {'affiliate': 'CrossFit Rejoice',
#     'breakdown': '110 reps\n347 lb.',
#     'heat': '',
#     'judge': 'Derek Geels',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '63',
#     'scaled': '0',
#     'score': '11100476',
#     'scoreDisplay': '4:04',
#     'scoreIdentifier': 'c12620ae4febf37da81a',
#     'time': 244,
#     'video': '0'},
#    {'affiliate': 'CrossFit Rejoice',
#     'breakdown': '347 lb.',
#     'heat': '',
#     'judge': 'Derek Geels',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '349',
#     'scaled': '0',
#     'score': '13470476',
#     'scoreDisplay': '347 lb',
#     'scoreIdentifier': '8d4cbd369889955c1075',
#     'time': 244,
#     'video': '0'},
#    {'affiliate': 'CrossFit Rejoice',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n100 double-unders\n6 bar muscle-ups',
#     'heat': '',
#     'judge': 'Derek Geels',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '8',
#     'scaled': '0',
#     'score': '19220020',
#     'scoreDisplay': '922 reps',
#     'scoreIdentifier': 'cac3747ecbd33664a1d3',
#     'time': 820,
#     'video': '0'},
#    {'affiliate': 'CrossFit Rejoice',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Derek Geels',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '73',
#     'scaled': '0',
#     'score': '11650078',
#     'scoreDisplay': '7:42',
#     'scoreIdentifier': 'b522affc85ec1efc2099',
#     'time': 462,
#     'video': '0'},
#    {'affiliate': 'CrossFit Rejoice',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n10 thr.',
#     'heat': '',
#     'judge': 'Derek Geels',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '54',
#     'scaled': '0',
#     'score': '11780000',
#     'scoreDisplay': '178 reps',
#     'scoreIdentifier': 'db2d0d2a3e8a0ff1a4ed',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '5307',
#    'affiliateName': 'CrossFit Pallas',
#    'age': '28',
#    'competitorId': '20698',
#    'competitorName': 'Tim Paulson',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Tim',
#    'gender': 'M',
#    'height': '73 in',
#    'lastName': 'Paulson',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': 'c15ef-P20698_9-184.jpg',
#    'regionId': '11',
#    'regionName': 'North East',
#    'regionalCode': '4',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '215 lb'},
#   'nextStage': '',
#   'overallRank': '9',
#   'overallScore': '843',
#   'scores': [{'affiliate': 'CrossFit Pallas',
#     'breakdown': '14 rounds +\n4 toes-to-bars',
#     'heat': '',
#     'judge': 'Darrin Gardner',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '105',
#     'scaled': '0',
#     'score': '14520000',
#     'scoreDisplay': '452 reps',
#     'scoreIdentifier': '399014417ad34d617948',
#     'video': '0'},
#    {'affiliate': 'CrossFit Pallas',
#     'breakdown': '110 reps\n345 lb.',
#     'heat': '',
#     'judge': 'Darrin Gardner',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '78',
#     'scaled': '0',
#     'score': '11100474',
#     'scoreDisplay': '4:06',
#     'scoreIdentifier': 'd2651624204db3d5735f',
#     'time': 246,
#     'video': '0'},
#    {'affiliate': 'CrossFit Pallas',
#     'breakdown': '345 lb.',
#     'heat': '',
#     'judge': 'Darrin Gardner',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '415',
#     'scaled': '0',
#     'score': '13450474',
#     'scoreDisplay': '345 lb',
#     'scoreIdentifier': '2e5c73d734710c89df05',
#     'time': 246,
#     'video': '0'},
#    {'affiliate': 'CrossFit Pallas',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n14 snatches',
#     'heat': '',
#     'judge': 'Darrin Gardner',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '156',
#     'scaled': '0',
#     'score': '18100027',
#     'scoreDisplay': '810 reps',
#     'scoreIdentifier': 'bb9304d3bd5679bbca0d',
#     'time': 813,
#     'video': '0'},
#    {'affiliate': 'CrossFit Pallas',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Darrin Gardner',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '43',
#     'scaled': '0',
#     'score': '11650092',
#     'scoreDisplay': '7:28',
#     'scoreIdentifier': 'dbe315f096506bc1fe1a',
#     'time': 448,
#     'video': '0'},
#    {'affiliate': 'CrossFit Pallas',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n11 thr.',
#     'heat': '',
#     'judge': 'Darrin Gardner',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '46',
#     'scaled': '0',
#     'score': '11790000',
#     'scoreDisplay': '179 reps',
#     'scoreIdentifier': 'fb9ba255d44f214bffd3',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '3220',
#    'affiliateName': 'CrossFit Mayhem',
#    'age': '30',
#    'competitorId': '11435',
#    'competitorName': 'Richard Froning Jr.',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Richard',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Froning Jr.',
#    'postCompStatus': 'team',
#    'profession': '0',
#    'profilePicS3key': '35d67-P11435_11-184.jpg',
#    'regionId': '6',
#    'regionName': 'Central East',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '198 lb'},
#   'nextStage': '',
#   'overallRank': '10',
#   'overallScore': '848',
#   'scores': [{'affiliate': 'CrossFit Mayhem',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks\n13 calories',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '183',
#     'scaled': '0',
#     'score': '14470000',
#     'scoreDisplay': '447 reps',
#     'scoreIdentifier': '61aa44b5076528501acc',
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '110 reps\n343 lb.',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '129',
#     'scaled': '0',
#     'score': '11100469',
#     'scoreDisplay': '4:11',
#     'scoreIdentifier': '6c380611f65c18a87c85',
#     'time': 251,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '343 lb.',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '502',
#     'scaled': '0',
#     'score': '13430469',
#     'scoreDisplay': '343 lb',
#     'scoreIdentifier': '4c10becb4bc34ce35f73',
#     'time': 251,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n100 double-unders\n6 bar muscle-ups',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '7',
#     'scaled': '0',
#     'score': '19220022',
#     'scoreDisplay': '922 reps',
#     'scoreIdentifier': '4bf41eef3dd342bc657a',
#     'time': 818,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '11',
#     'scaled': '0',
#     'score': '11650128',
#     'scoreDisplay': '6:52',
#     'scoreIdentifier': '54293af5bde12ab423d8',
#     'time': 412,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mayhem',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n15 thr.',
#     'heat': '',
#     'judge': 'Darren Hunsucker',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '16',
#     'scaled': '0',
#     'score': '11830000',
#     'scoreDisplay': '183 reps',
#     'scoreIdentifier': '4d6c00e16df3ad07d5e8',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '18913',
#    'affiliateName': 'CrossFit Exceed',
#    'age': '23',
#    'competitorId': '473719',
#    'competitorName': 'Michael Palomba',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Michael',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Palomba',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': 'a23fe-P473719_5-184.jpg',
#    'regionId': '11',
#    'regionName': 'North East',
#    'regionalCode': '4',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '195 lb'},
#   'nextStage': '',
#   'overallRank': '11',
#   'overallScore': '887',
#   'scores': [{'affiliate': 'CrossFit Exceed',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n10 clean & jerks',
#     'heat': '',
#     'judge': 'Todd Vitale',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '20',
#     'scaled': '0',
#     'score': '14660000',
#     'scoreDisplay': '466 reps',
#     'scoreIdentifier': '83884c9cb49cf023b9ca',
#     'video': '0'},
#    {'affiliate': 'CrossFit Exceed',
#     'breakdown': '110 reps\n377 lb.',
#     'heat': '',
#     'judge': 'Todd Vitale',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '304',
#     'scaled': '0',
#     'score': '11100460',
#     'scoreDisplay': '4:20',
#     'scoreIdentifier': 'a9188e52c546185a2f82',
#     'time': 260,
#     'video': '0'},
#    {'affiliate': 'CrossFit Exceed',
#     'breakdown': '377 lb.',
#     'heat': '',
#     'judge': 'Todd Vitale',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '26',
#     'scaled': '0',
#     'score': '13770460',
#     'scoreDisplay': '377 lb',
#     'scoreIdentifier': '71a1d7c24530d6d591cb',
#     'time': 260,
#     'video': '0'},
#    {'affiliate': 'CrossFit Exceed',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n4 snatches',
#     'heat': '',
#     'judge': 'Todd Vitale',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '283',
#     'scaled': '0',
#     'score': '18000007',
#     'scoreDisplay': '800 reps',
#     'scoreIdentifier': 'bc1a813cec662304558b',
#     'time': 833,
#     'video': '0'},
#    {'affiliate': 'CrossFit Exceed',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Todd Vitale',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '156',
#     'scaled': '0',
#     'score': '11650041',
#     'scoreDisplay': '8:19',
#     'scoreIdentifier': '3f24f43b2bb2c048ee82',
#     'time': 499,
#     'video': '0'},
#    {'affiliate': 'CrossFit Exceed',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n6 thr.',
#     'heat': '',
#     'judge': 'Todd Vitale',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '98',
#     'scaled': '0',
#     'score': '11740000',
#     'scoreDisplay': '174 reps',
#     'scoreIdentifier': '28940a4f9770d2822696',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '4860',
#    'affiliateName': 'CrossFit Hengill',
#    'age': '25',
#    'competitorId': '81616',
#    'competitorName': 'Björgvin Karl Guðmundsson',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Björgvin Karl',
#    'gender': 'M',
#    'height': '178 cm',
#    'lastName': 'Guðmundsson',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '4c5dc-P81616_4-184.jpg',
#    'regionId': '22',
#    'regionName': 'Europe North',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '185 lb'},
#   'nextStage': '',
#   'overallRank': '12',
#   'overallScore': '996',
#   'scores': [{'affiliate': 'CrossFit Hengill',
#     'breakdown': '14 rounds +\n8 toes-to-bars\n10 clean & jerks\n8 calories',
#     'heat': '',
#     'judge': 'Maria Run Thorsteinsdottir',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '9',
#     'scaled': '0',
#     'score': '14740000',
#     'scoreDisplay': '474 reps',
#     'scoreIdentifier': '04d73936d432b99635b3',
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '110 reps\n336 lb.',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '110',
#     'scaled': '0',
#     'score': '11100471',
#     'scoreDisplay': '4:09',
#     'scoreIdentifier': 'f1e766fda5c34e608e7f',
#     'time': 249,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '336 lb.',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '785',
#     'scaled': '0',
#     'score': '13360471',
#     'scoreDisplay': '336 lb',
#     'scoreIdentifier': '0259ee04ad178aa27d50',
#     'time': 249,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n100 double-unders\n3 bar muscle-ups',
#     'heat': '',
#     'judge': 'Throstur Olason',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '13',
#     'scaled': '0',
#     'score': '19190014',
#     'scoreDisplay': '919 reps',
#     'scoreIdentifier': '3e04150cd68d7f0c22b1',
#     'time': 826,
#     'video': '0'},
#    {'affiliate': 'CrossFit Hengill',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Maria Run Thorsteinsdottir',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '33',
#     'scaled': '0',
#     'score': '11650101',
#     'scoreDisplay': '7:19',
#     'scoreIdentifier': '33375eab4880adfc4261',
#     'time': 439,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n11 thr.',
#     'heat': '',
#     'judge': 'Heidar Ingi Heidarsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '46',
#     'scaled': '0',
#     'score': '11790000',
#     'scoreDisplay': '179 reps',
#     'scoreIdentifier': '62b08ba5d034528c3ac3',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '7991',
#    'affiliateName': 'CrossFit Mentality',
#    'age': '30',
#    'competitorId': '34796',
#    'competitorName': 'Scott Panchik',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Scott',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Panchik',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': 'e23e0-P34796_8-184.jpg',
#    'regionId': '6',
#    'regionName': 'Central East',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '187 lb'},
#   'nextStage': '',
#   'overallRank': '13',
#   'overallScore': '1045',
#   'scores': [{'affiliate': 'CrossFit Mentality',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n6 clean & jerks',
#     'heat': '',
#     'judge': 'Christin Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '631',
#     'scaled': '0',
#     'score': '14300000',
#     'scoreDisplay': '430 reps',
#     'scoreIdentifier': '80e73cb32ab99d716348',
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '110 reps\n356 lb.',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '78',
#     'scaled': '0',
#     'score': '11100474',
#     'scoreDisplay': '4:06',
#     'scoreIdentifier': 'f0216e17ad88778774d6',
#     'time': 246,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '356 lb.',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '191',
#     'scaled': '0',
#     'score': '13560474',
#     'scoreDisplay': '356 lb',
#     'scoreIdentifier': '2d4379db4d3f3dae7e03',
#     'time': 246,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches',
#     'heat': '',
#     'judge': 'Christin Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '104',
#     'scaled': '0',
#     'score': '18160050',
#     'scoreDisplay': '816 reps',
#     'scoreIdentifier': 'f636eb1bec91a45e511d',
#     'time': 790,
#     'video': '0'},
#    {'affiliate': 'CrossFit Fury',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Lisa Ray',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '25',
#     'scaled': '0',
#     'score': '11650108',
#     'scoreDisplay': '7:12',
#     'scoreIdentifier': '898e044561b197f221b7',
#     'time': 432,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n15 thr.',
#     'heat': '',
#     'judge': 'Christin Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '16',
#     'scaled': '0',
#     'score': '11830000',
#     'scoreDisplay': '183 reps',
#     'scoreIdentifier': '84263e72f420fd364048',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '600',
#    'affiliateName': 'CrossFit Invictus',
#    'age': '27',
#    'competitorId': '21292',
#    'competitorName': 'Garret Fisher',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Garret',
#    'gender': 'M',
#    'height': '74 in',
#    'lastName': 'Fisher',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '47f76-P21292_16-184.jpg',
#    'regionId': '19',
#    'regionName': 'West Coast',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '217 lb'},
#   'nextStage': '',
#   'overallRank': '14',
#   'overallScore': '1057',
#   'scores': [{'affiliate': 'CrossFit Invictus',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks',
#     'heat': '',
#     'judge': 'Santino Marini',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '446',
#     'scaled': '0',
#     'score': '14340000',
#     'scoreDisplay': '434 reps',
#     'scoreIdentifier': '88dc2c01495bca684848',
#     'video': '0'},
#    {'affiliate': 'CrossFit Invictus Sorrento Valley',
#     'breakdown': '110 reps\n382 lb.',
#     'heat': '',
#     'judge': 'Santino Marini',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '276',
#     'scaled': '0',
#     'score': '11100461',
#     'scoreDisplay': '4:19',
#     'scoreIdentifier': '4809b63d19b2921f28cf',
#     'time': 259,
#     'video': '0'},
#    {'affiliate': 'CrossFit Invictus Sorrento Valley',
#     'breakdown': '382 lb.',
#     'heat': '',
#     'judge': 'Santino Marini',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '18',
#     'scaled': '0',
#     'score': '13820461',
#     'scoreDisplay': '382 lb',
#     'scoreIdentifier': '42ece2cc178cb905df43',
#     'time': 259,
#     'video': '0'},
#    {'affiliate': 'CrossFit Invictus',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n4 snatches',
#     'heat': '',
#     'judge': 'Kirsten Ahrendt',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '280',
#     'scaled': '0',
#     'score': '18000008',
#     'scoreDisplay': '800 reps',
#     'scoreIdentifier': 'd6a82cb9970468734c96',
#     'time': 832,
#     'video': '0'},
#    {'affiliate': 'CrossFit Invictus Sorrento Valley',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Santino Marini',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '21',
#     'scaled': '0',
#     'score': '11650112',
#     'scoreDisplay': '7:08',
#     'scoreIdentifier': 'ef3a39876b76e672fd39',
#     'time': 428,
#     'video': '0'},
#    {'affiliate': 'CrossFit Invictus',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n15 thr.',
#     'heat': '',
#     'judge': 'Santino Marini',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '16',
#     'scaled': '0',
#     'score': '11830000',
#     'scoreDisplay': '183 reps',
#     'scoreIdentifier': '04e13ecae846710b2fb6',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '2314',
#    'affiliateName': 'CrossFit Cedar Rapids',
#    'age': '26',
#    'competitorId': '243026',
#    'competitorName': 'Dylan Martin',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Dylan',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Martin',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '49a99-P243026_6-184.jpg',
#    'regionId': '10',
#    'regionName': 'North Central',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '190 lb'},
#   'nextStage': '',
#   'overallRank': '15',
#   'overallScore': '1083',
#   'scores': [{'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '14 rounds +\n0 toes-to-bars',
#     'heat': '',
#     'judge': 'Brandon Steggall',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '143',
#     'scaled': '0',
#     'score': '14480000',
#     'scoreDisplay': '448 reps',
#     'scoreIdentifier': '240d62bc591cb8cb0929',
#     'video': '0'},
#    {'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '110 reps\n342 lb.',
#     'heat': '',
#     'judge': 'Brandon Steggall',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '249',
#     'scaled': '0',
#     'score': '11100462',
#     'scoreDisplay': '4:18',
#     'scoreIdentifier': 'df9c2ff5408e4f2762b8',
#     'time': 258,
#     'video': '0'},
#    {'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '342 lb.',
#     'heat': '',
#     'judge': 'Brandon Steggall',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '528',
#     'scaled': '0',
#     'score': '13420462',
#     'scoreDisplay': '342 lb',
#     'scoreIdentifier': '151e39c3635acdf328e2',
#     'time': 258,
#     'video': '0'},
#    {'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n26 double-unders',
#     'heat': '',
#     'judge': 'Brandon Steggall',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '60',
#     'scaled': '0',
#     'score': '18420069',
#     'scoreDisplay': '842 reps',
#     'scoreIdentifier': '73530fc92584e574b45a',
#     'time': 771,
#     'video': '0'},
#    {'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Brandon Steggall',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '49',
#     'scaled': '0',
#     'score': '11650088',
#     'scoreDisplay': '7:32',
#     'scoreIdentifier': 'a620a551098daafcb04d',
#     'time': 452,
#     'video': '0'},
#    {'affiliate': 'CrossFit Cedar Rapids',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n10 thr.',
#     'heat': '',
#     'judge': 'Brandon Steggall',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '54',
#     'scaled': '0',
#     'score': '11780000',
#     'scoreDisplay': '178 reps',
#     'scoreIdentifier': '10e5a0c3c58e457632dc',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '3836',
#    'affiliateName': 'CrossFit 061',
#    'age': '34',
#    'competitorId': '5312',
#    'competitorName': 'Nicholas Urankar',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Nicholas',
#    'gender': 'M',
#    'height': '70 in',
#    'lastName': 'Urankar',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '9f1e0-P5312_6-184.jpg',
#    'regionId': '6',
#    'regionName': 'Central East',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '192 lb'},
#   'nextStage': '',
#   'overallRank': '16',
#   'overallScore': '1103',
#   'scores': [{'affiliate': 'CrossFit 061',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks\n8 calories',
#     'heat': '',
#     'judge': 'Azariah Price',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '266',
#     'scaled': '0',
#     'score': '14420000',
#     'scoreDisplay': '442 reps',
#     'scoreIdentifier': '159095a29b362e5936a2',
#     'video': '0'},
#    {'affiliate': 'CrossFit 061',
#     'breakdown': '110 reps\n376 lb.',
#     'heat': '',
#     'judge': 'Ben rou',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '393',
#     'scaled': '0',
#     'score': '11100456',
#     'scoreDisplay': '4:24',
#     'scoreIdentifier': '2531ea8e855fdfec8ff5',
#     'time': 264,
#     'video': '0'},
#    {'affiliate': 'CrossFit 061',
#     'breakdown': '376 lb.',
#     'heat': '',
#     'judge': 'Ben rou',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '35',
#     'scaled': '0',
#     'score': '13760456',
#     'scoreDisplay': '376 lb',
#     'scoreIdentifier': '7be0bf79eaa4acd0f911',
#     'time': 264,
#     'video': '0'},
#    {'affiliate': 'CrossFit 061',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n8 snatches',
#     'heat': '',
#     'judge': 'Carole Turnbo',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '208',
#     'scaled': '0',
#     'score': '18040018',
#     'scoreDisplay': '804 reps',
#     'scoreIdentifier': '95263934849dd547578d',
#     'time': 822,
#     'video': '0'},
#    {'affiliate': 'CrossFit 061',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Jeff Borders',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '45',
#     'scaled': '0',
#     'score': '11650091',
#     'scoreDisplay': '7:29',
#     'scoreIdentifier': '78d78f40ad3cae38ce2a',
#     'time': 449,
#     'video': '0'},
#    {'affiliate': 'CrossFit 061',
# ...
#     'heat': '',
#     'judge': 'Max Dokuchaev',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '503',
#     'scaled': '0',
#     'score': '11620032',
#     'scoreDisplay': '162 reps',
#     'scoreIdentifier': 'c76ab5ef6cd5069de10a',
#     'time': 508,
#     'video': '0'},
#    {'affiliate': 'CrossFit Idol',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n12 thr.',
#     'heat': '',
#     'judge': 'Max Dokuchaev',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '34',
#     'scaled': '0',
#     'score': '11800000',
#     'scoreDisplay': '180 reps',
#     'scoreIdentifier': 'b09110ba771ff526f74b',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '2025',
#    'affiliateName': 'Reebok CrossFit Reykjavík',
#    'age': '31',
#    'competitorId': '18543',
#    'competitorName': 'Frederik Aegidius',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Frederik',
#    'gender': 'M',
#    'height': '174 cm',
#    'lastName': 'Aegidius',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': 'ef40c-P18543_11-184.jpg',
#    'regionId': '22',
#    'regionName': 'Europe North',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '84 kg'},
#   'nextStage': '',
#   'overallRank': '46',
#   'overallScore': '1752',
#   'scores': [{'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks\n13 calories',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '183',
#     'scaled': '0',
#     'score': '14470000',
#     'scoreDisplay': '447 reps',
#     'scoreIdentifier': 'eac539d9e3701f18bea6',
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '110 reps\n333 lb.',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '26',
#     'scaled': '0',
#     'score': '11100482',
#     'scoreDisplay': '3:58',
#     'scoreIdentifier': 'e375df5a10e4ccb31c63',
#     'time': 238,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '333 lb.',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '976',
#     'scaled': '0',
#     'score': '13330482',
#     'scoreDisplay': '333 lb',
#     'scoreIdentifier': '1f0559f34b7d251d27cd',
#     'time': 238,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n100 double-unders\n2 bar muscle-ups',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '14',
#     'scaled': '0',
#     'score': '19180012',
#     'scoreDisplay': '918 reps',
#     'scoreIdentifier': '74e816b6a645f9c9dec0',
#     'time': 828,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '322',
#     'scaled': '0',
#     'score': '11650010',
#     'scoreDisplay': '8:50',
#     'scoreIdentifier': 'bdeace6aa64cfa64571f',
#     'time': 530,
#     'video': '0'},
#    {'affiliate': 'Reebok CrossFit Reykjavík',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU',
#     'heat': '',
#     'judge': 'Evert Viglundsson',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '231',
#     'scaled': '0',
#     'score': '11680000',
#     'scoreDisplay': '168 reps',
#     'scoreIdentifier': '33cc67efbee4fbf6ac4c',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '0',
#    'affiliateName': '',
#    'age': '26',
#    'competitorId': '14960',
#    'competitorName': 'Travis Williams',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Travis',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Williams',
#    'postCompStatus': 'team',
#    'profession': '0',
#    'profilePicS3key': '4dab1-P14960_11-184.jpg',
#    'regionId': '14',
#    'regionName': 'South Central',
#    'regionalCode': '7',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '202 lb'},
#   'nextStage': '',
#   'overallRank': '47',
#   'overallScore': '1775',
#   'scores': [{'affiliate': 'CrossFit Kemah',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n7 clean & jerks',
#     'heat': '',
#     'judge': 'Scott Perkins',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '593',
#     'scaled': '0',
#     'score': '14310000',
#     'scoreDisplay': '431 reps',
#     'scoreIdentifier': '019aaa4af99523d7aebe',
#     'video': '0'},
#    {'affiliate': 'U Can CrossFit',
#     'breakdown': '110 reps\n342 lb.',
#     'heat': '',
#     'judge': 'Jason Petrillo',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '369',
#     'scaled': '0',
#     'score': '11100457',
#     'scoreDisplay': '4:23',
#     'scoreIdentifier': '2cb778c0f5f32c266352',
#     'time': 263,
#     'video': '0'},
#    {'affiliate': 'U Can CrossFit',
#     'breakdown': '342 lb.',
#     'heat': '',
#     'judge': 'Jason Petrillo',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '532',
#     'scaled': '0',
#     'score': '13420457',
#     'scoreDisplay': '342 lb',
#     'scoreIdentifier': 'add1c2327e8773ebf54a',
#     'time': 263,
#     'video': '0'},
#    {'affiliate': 'Skyline CrossFit',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n5 snatches',
#     'heat': '',
#     'judge': 'Todd Widman',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '250',
#     'scaled': '0',
#     'score': '18010012',
#     'scoreDisplay': '801 reps',
#     'scoreIdentifier': '4fcc156390dbfefca3ec',
#     'time': 828,
#     'video': '0'},
#    {'affiliate': 'CrossFit Kemah',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Jordan Cook',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '28',
#     'scaled': '0',
#     'score': '11650105',
#     'scoreDisplay': '7:15',
#     'scoreIdentifier': '6fbc5c1705341d82d6a6',
#     'time': 435,
#     'video': '0'},
#    {'affiliate': 'CrossFit Rejoice',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n21 thr.',
#     'heat': '',
#     'judge': 'Logan Collins',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '3',
#     'scaled': '0',
#     'score': '11890000',
#     'scoreDisplay': '189 reps',
#     'scoreIdentifier': 'e6000b883c84ff3a0e7e',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '9043',
#    'affiliateName': 'CrossFit Carv',
#    'age': '26',
#    'competitorId': '180106',
#    'competitorName': 'Zeke Grove',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Zeke',
#    'gender': 'M',
#    'height': '169 cm',
#    'lastName': 'Grove',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '4002f-P180106_6-184.jpg',
#    'regionId': '21',
#    'regionName': 'Australasia',
#    'regionalCode': '0',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '182 lb'},
#   'nextStage': '',
#   'overallRank': '48',
#   'overallScore': '1780',
#   'scores': [{'affiliate': 'Live Elite CrossFit',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks\n6 calories',
#     'heat': '',
#     'judge': 'James Toole',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '305',
#     'scaled': '0',
#     'score': '14400000',
#     'scoreDisplay': '440 reps',
#     'scoreIdentifier': 'dbad33b48134a9d11a8e',
#     'video': '0'},
#    {'affiliate': 'Live Elite CrossFit',
#     'breakdown': '110 reps\n333 lb.',
#     'heat': '',
#     'judge': 'James Toole',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '5',
#     'scaled': '0',
#     'score': '11100491',
#     'scoreDisplay': '3:49',
#     'scoreIdentifier': '84e0041e5ddc55cf2705',
#     'time': 229,
#     'video': '0'},
#    {'affiliate': 'Live Elite CrossFit',
#     'breakdown': '333 lb.',
#     'heat': '',
#     'judge': 'James Toole',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '975',
#     'scaled': '0',
#     'score': '13330491',
#     'scoreDisplay': '333 lb',
#     'scoreIdentifier': '1e47d403ef3cca49f0c4',
#     'time': 229,
#     'video': '0'},
#    {'affiliate': 'Live Elite CrossFit',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n1 snatches',
#     'heat': '',
#     'judge': 'James Toole',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '320',
#     'scaled': '0',
#     'score': '17970003',
#     'scoreDisplay': '797 reps',
#     'scoreIdentifier': '6515a20a883c48891c22',
#     'time': 837,
#     'video': '0'},
#    {'affiliate': 'Live Elite CrossFit',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'James Toole',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '99',
#     'scaled': '0',
#     'score': '11650067',
#     'scoreDisplay': '7:53',
#     'scoreIdentifier': 'a749160e5c0956d3ac56',
#     'time': 473,
#     'video': '0'},
#    {'affiliate': 'Live Elite CrossFit',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 21 PU \n8 thr.',
#     'heat': '',
#     'judge': 'James Toole',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '76',
#     'scaled': '0',
#     'score': '11760000',
#     'scoreDisplay': '176 reps',
#     'scoreIdentifier': '7bf918ba85741c7133b2',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '7991',
#    'affiliateName': 'CrossFit Mentality',
#    'age': '22',
#    'competitorId': '310970',
#    'competitorName': 'Saxon Panchik',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Saxon',
#    'gender': 'M',
#    'height': '69 in',
#    'lastName': 'Panchik',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '00087-P310970_11-184.jpg',
#    'regionId': '6',
#    'regionName': 'Central East',
#    'regionalCode': '3',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '175 lb'},
#   'nextStage': '',
#   'overallRank': '49',
#   'overallScore': '1781',
#   'scores': [{'affiliate': 'CrossFit Mentality',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '446',
#     'scaled': '0',
#     'score': '14340000',
#     'scoreDisplay': '434 reps',
#     'scoreIdentifier': '8da70731a929bcc986f6',
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '110 reps\n337 lb.',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '100',
#     'scaled': '0',
#     'score': '11100472',
#     'scoreDisplay': '4:08',
#     'scoreIdentifier': 'da9f9c492a9983c8f44d',
#     'time': 248,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '337 lb.',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '679',
#     'scaled': '0',
#     'score': '13370472',
#     'scoreDisplay': '337 lb',
#     'scoreIdentifier': '37843c934d3c91d2b08a',
#     'time': 248,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n100 double-unders\n20 snatches\n33 double-unders',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '56',
#     'scaled': '0',
#     'score': '18490070',
#     'scoreDisplay': '849 reps',
#     'scoreIdentifier': '1fb7f88c71061deb84a9',
#     'time': 770,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '139',
#     'scaled': '0',
#     'score': '11650048',
#     'scoreDisplay': '8:12',
#     'scoreIdentifier': 'f768afe1400e25c6b810',
#     'time': 492,
#     'video': '0'},
#    {'affiliate': 'CrossFit Mentality',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 18 PU',
#     'heat': '',
#     'judge': 'Spencer Panchik',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '361',
#     'scaled': '0',
#     'score': '11650000',
#     'scoreDisplay': '165 reps',
#     'scoreIdentifier': '9079a7c3351fe0e39120',
#     'video': '0'}],
#   'ui': {'highlight': False}},
#  {'entrant': {'affiliateId': '7104',
#    'affiliateName': 'CrossFit Passion',
#    'age': '27',
#    'competitorId': '1690',
#    'competitorName': 'Travis Mayer',
#    'countryShortCode': '',
#    'divisionId': '1',
#    'firstName': 'Travis',
#    'gender': 'M',
#    'height': '71 in',
#    'lastName': 'Mayer',
#    'postCompStatus': 'accepted',
#    'profession': '0',
#    'profilePicS3key': '9de68-P1690_5-184.jpg',
#    'regionId': '15',
#    'regionName': 'South East',
#    'regionalCode': '1',
#    'status': 'ACT',
#    'teamCaptain': '0',
#    'weight': '195 lb'},
#   'nextStage': '',
#   'overallRank': '50',
#   'overallScore': '1799',
#   'scores': [{'affiliate': 'CrossFit Passion',
#     'breakdown': '13 rounds +\n8 toes-to-bars\n10 clean & jerks\n12 calories',
#     'heat': '',
#     'judge': 'john maloney',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 1,
#     'rank': '201',
#     'scaled': '0',
#     'score': '14460000',
#     'scoreDisplay': '446 reps',
#     'scoreIdentifier': '7275f8995601d1a785f2',
#     'video': '0'},
#    {'affiliate': 'CrossFit Passion',
#     'breakdown': '110 reps\n352 lb.',
#     'heat': '',
#     'judge': 'Brannen Dorman',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 2,
#     'rank': '276',
#     'scaled': '0',
#     'score': '11100461',
#     'scoreDisplay': '4:19',
#     'scoreIdentifier': 'ccb4518b4932d2071618',
#     'time': 259,
#     'video': '0'},
#    {'affiliate': 'CrossFit Passion',
#     'breakdown': '352 lb.',
#     'heat': '',
#     'judge': 'Brannen Dorman',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 3,
#     'rank': '275',
#     'scaled': '0',
#     'score': '13520461',
#     'scoreDisplay': '352 lb',
#     'scoreIdentifier': '035c07845ea522f4456a',
#     'time': 259,
#     'video': '0'},
#    {'affiliate': 'CrossFit Passion',
#     'breakdown': '1 round +\n100 double-unders\n20 overhead squats\n100 double-unders\n12 ring muscle-ups\n80 double-unders',
#     'heat': '',
#     'judge': 'john maloney',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 4,
#     'rank': '433',
#     'scaled': '0',
#     'score': '17760157',
#     'scoreDisplay': '776 reps',
#     'scoreIdentifier': '6a3c992f133771935ccc',
#     'time': 683,
#     'video': '0'},
#    {'affiliate': 'CrossFit Passion',
#     'breakdown': '165 reps',
#     'heat': '',
#     'judge': 'john maloney',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 5,
#     'rank': '12',
#     'scaled': '0',
#     'score': '11650127',
#     'scoreDisplay': '6:53',
#     'scoreIdentifier': '7ff587b3a83c2e3395f5',
#     'time': 413,
#     'video': '0'},
#    {'affiliate': 'CrossFit Passion',
#     'breakdown': '3 thr. 3 PU \n6 thr. 6 PU \n9 thr. 9 PU \n12 thr. 12 PU \n15 thr. 15 PU \n18 thr. 18 PU \n21 thr. 13 PU',
#     'heat': '',
#     'judge': 'john maloney',
#     'lane': '',
#     'mobileScoreDisplay': '',
#     'ordinal': 6,
#     'rank': '602',
#     'scaled': '0',
#     'score': '11600000',
#     'scoreDisplay': '160 reps',
#     'scoreIdentifier': '5ea10034f85019587b7a',
#     'video': '0'}],
#   'ui': {'highlight': False}}]
